# %%
# !pip install wget
import wget
import os
# Out:
# ...
#   Created wheel for wget: filename=wget-3.2-cp36-none-any.whl size=9682 sha256=698145eb11eefbcce699b38c305c005f5747a0cae18fa6898ef6012f5c261478
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# ...

# %%
url = "https://people.eecs.berkeley.edu/~tinghuiz/projects/pix2pix/datasets/facades.tar.gz"
wget.download(url, '.')
# !tar -zxvf facades.tar.gz
# Out:
# facades/
# facades/test/
# facades/test/27.jpg
# facades/test/5.jpg
# facades/test/72.jpg
# facades/test/1.jpg
# facades/test/10.jpg
# facades/test/100.jpg
# facades/test/101.jpg
# facades/test/102.jpg
# facades/test/103.jpg
# facades/test/104.jpg
# facades/test/105.jpg
# facades/test/106.jpg
# facades/test/11.jpg
# facades/test/12.jpg
# facades/test/13.jpg
# facades/test/14.jpg
# facades/test/15.jpg
# facades/test/16.jpg
# facades/test/17.jpg
# facades/test/18.jpg
# facades/test/19.jpg
# facades/test/2.jpg
# facades/test/20.jpg
# facades/test/21.jpg
# facades/test/22.jpg
# facades/test/23.jpg
# facades/test/24.jpg
# facades/test/25.jpg
# facades/test/26.jpg
# facades/test/50.jpg
# facades/test/51.jpg
# facades/test/52.jpg
# facades/test/53.jpg
# facades/test/54.jpg
# facades/test/55.jpg
# facades/test/56.jpg
# facades/test/57.jpg
# facades/test/58.jpg
# facades/test/59.jpg
# facades/test/6.jpg
# facades/test/60.jpg
# facades/test/61.jpg
# facades/test/62.jpg
# facades/test/63.jpg
# ...

# %%
# !ls
# Out:
# facades  facades.tar.gz  sample_data

# %%
# !cd facades

# %%
# !ls
# Out:
# facades  facades.tar.gz  sample_data

# %%
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
files_val = glob.glob('facades/val/*')

# %%
val_pass = [i for i in files_val]

# %%
val_input = [cv2.imread(i, cv2.IMREAD_COLOR)[:,256:,:] for i in val_pass]

# %%
val_images = np.array(val_images)

# %%
val_images.shape
# Out:
# (100, 256, 512, 3)

# %%
image = cv2.imread(val_pass[0], cv2.IMREAD_COLOR)[:,256:,:]

# %%
image.shape
# Out:
# (256, 256, 3)

# %%
plt.imshow(image)

# %%
image[:,:256,:].shape
# Out:
# (256, 256, 3)

# %%
image[:,256:,:].shape
# Out:
# (256, 256, 3)
